# %%
# Import dependencies 
import pandas as pd

# %%
# Import CSV with horse racing data from 2020
df = pd.read_csv(r"C:\Users\vidul\Documents\UCB Bootcamp Files\Projects\Project 4\Mustang\Resources\merged_data.csv")
df.head()
# Out:
# c:\Users\vidul\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (11,19,46) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Unnamed: 0    rid    course   time      date  \
# 0           0  10312  Fakenham  02:55  20/01/01
# 1           1  10312  Fakenham  02:55  20/01/01
# 2           2  10312  Fakenham  02:55  20/01/01
# 3           3  10312  Fakenham  02:55  20/01/01
# 4           4  10312  Fakenham  02:55  20/01/01
#
#                                   title   rclass band  ages distance  ...  \
# 0  Happy New Year Maiden Hurdle (Div I)  Class 4  NaN  4yo+       2m  ...
# 1  Happy New Year Maiden Hurdle (Div I)  Class 4  NaN  4yo+       2m  ...
# 2  Happy New Year Maiden Hurdle (Div I)  Class 4  NaN  4yo+       2m  ...
# 3  Happy New Year Maiden Hurdle (Div I)  Class 4  NaN  4yo+       2m  ...
# ...

# %%
df.groupby("countryCode").count().sort_values(by="course", ascending=False).head(8)
# Out:
#              Unnamed: 0    rid  course   time   date  title  rclass   band  \
# countryCode
# GB                67214  67214   67214  67214  67214  67214   67157  43940
# IE                27291  27291   27291  27291  27291  27291       0   8970
# FR                19964  19964   19964  19964  19964  19964       0      0
# US                15263  15263   15263  15263  15263  15263       0      0
# HK                 9353   9353    9353   9353   9353   9353       0      0
# AU                 3497   3497    3497   3497   3497   3497       0      0
# AE                 1884   1884    1884   1884   1884   1884       0   1113
# JP                 1557   1557    1557   1557   1557   1557       0      0
#
#               ages  distance  ...     OR  father  mother  gfather  runners  \
# countryCode                   ...
# GB           67214     67214  ...  51560   67154   67154    67125    67154
# IE           27291     27291  ...  17000   27288   27288    27288    27288
# ...

# %%
df_columns = df[["age", "weight", "RPR", "TR", "OR", "runners", "metric", "trainerName", "jockeyName", "condition", "res_win"]]

# %%
df_columns = df_columns.dropna()

# %%
df_horse_features = df_columns.drop(columns="res_win")
df_horse_target = df_columns["res_win"]

# %%
print(df_horse_features.size)
print(df_horse_features.dtypes)
print(df_horse_target.dtypes)
# Out:
# 285110
# age            float64
# weight         float64
# RPR            float64
# TR             float64
# OR             float64
# runners        float64
# metric         float64
# trainerName     object
# jockeyName      object
# condition       object
# dtype: object
# float64
