# %% [markdown]
# # ML Model Horse Racing Predictions
# #### Create an ML model that can predict whether a horse has a good chance of winning a race, based on the horse's features

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
cleaned_2020_2019_df = pd.read_csv("Data_Racing/International_Data/cleaned_2020_2019_df.csv")
cleaned_2020_2019_df.head()
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# 2023-07-19 19:41:41.674105: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#    Unnamed: 0  ages  metric  ncond  age  saddle  decimalPrice  isFav   RPR  \
# 0           0  3yo+  1407.0      1  5.0     3.0      0.200000      0  63.0
# 1           1  3yo+  1407.0      1  6.0     7.0      0.333333      1  67.0
# 2           2  3yo+  1407.0      1  3.0    11.0      0.004587      0  49.0
# 3           5  3yo+  1407.0      1  4.0     9.0      0.027778      0  46.0
# 4           7  3yo+  1407.0      1  4.0     2.0      0.004975      0  45.0
#
#    TR    OR        father  weight  res_win
# 0 NaN  56.0         Makfi      57      0.0
# 1 NaN  53.0      Commands      56      0.0
# 2 NaN  49.0  All Too Hard      54      0.0
# 3 NaN  52.0    Showcasing      55      0.0
# 4 NaN  57.0        Kodiac      57      0.0

# %%
cleaned_2020_2019_df = cleaned_2020_2019_df.drop(columns = "Unnamed: 0")

# %%
# Determine the number of unique values in each column.
cleaned_2020_2019_df.nunique()
# Out:
# ages             24
# metric           61
# ncond            18
# age              15
# saddle           39
# decimalPrice    600
# isFav             2
# RPR             178
# TR              170
# OR              173
# father          413
# weight           36
# res_win           2
# dtype: int64

# %% [markdown]
# ## Select equal res_win values

# %%
# Look at value counts for binning
res_win_counts = cleaned_2020_2019_df["res_win"].value_counts()
class_count = res_win_counts.min()
class_count
# Out:
# 26108

# %%
res_win_equal = pd.concat([cleaned_2020_2019_df[cleaned_2020_2019_df.res_win==0].sample(n=class_count), 
                           cleaned_2020_2019_df[cleaned_2020_2019_df.res_win==1].sample(n=class_count)])
res_win_equal = res_win_equal.sort_index()
res_win_equal = res_win_equal.dropna()
res_win_equal
# Out:
#         ages  metric  ncond   age  saddle  decimalPrice  isFav    RPR     TR  \
# 10      5yo+  4827.0     10   9.0     1.0      0.090909      0  129.0  105.0
# 12      5yo+  4827.0     10  10.0     7.0      0.058824      0   95.0   75.0
# 15      4yo+  3921.5      1   8.0     4.0      0.421053      0  123.0   72.0
# 20      4yo+  3116.5      1   5.0     7.0      0.111111      0  128.0  113.0
# 29      5yo+  5028.0      1   8.0     2.0      0.250000      0  131.0   86.0
# ...      ...     ...    ...   ...     ...           ...    ...    ...    ...
# 253195  4yo+  3116.5      5   5.0     1.0      0.117647      0  121.0  100.0
# 253196  4yo+  4022.0      5   7.0     5.0      0.153846      0  144.0   82.0
# 253197  4yo+  4022.0      5   7.0     4.0      0.117647      0  137.0   75.0
# 253205  4yo+  4725.5      9   8.0     1.0      0.076923      0  141.0    3.0
# 253245  4yo+  5329.5      5   7.0     2.0      0.250000      1  107.0   10.0
#
#            OR            father  weight  res_win
# 10      132.0  Robin Des Champs      76      0.0
# 12      119.0           Alflora      70      0.0
# 15      130.0      Indian River      69      1.0
# 20      120.0         Shamardal      66      1.0
# 29      120.0        Presenting      69      1.0
# ...       ...               ...     ...      ...
# 253195  127.0          Kapgarde      76      0.0
# 253196  129.0         Poliglote      70      1.0
# 253197  129.0   Midnight Legend      70      0.0
# 253205  139.0           Shantou      75      1.0
# 253245  102.0   Midnight Legend      70      1.0
#
# [20955 rows x 13 columns]

# %% [markdown]
# ## Convert and Standardize Data

# %%
# Convert categorical data to numeric with `pd.get_dummies`
converted_data = pd.get_dummies(res_win_equal)
converted_data.head()
# Out:
#     metric  ncond   age  saddle  decimalPrice  isFav    RPR     TR     OR  \
# 10  4827.0     10   9.0     1.0      0.090909      0  129.0  105.0  132.0
# 12  4827.0     10  10.0     7.0      0.058824      0   95.0   75.0  119.0
# 15  3921.5      1   8.0     4.0      0.421053      0  123.0   72.0  130.0
# 20  3116.5      1   5.0     7.0      0.111111      0  128.0  113.0  120.0
# 29  5028.0      1   8.0     2.0      0.250000      0  131.0   86.0  120.0
#
#     weight  ...  father_Whipper  father_Whitmore's Conn  father_Winged Love  \
# 10      76  ...               0                       0                   0
# 12      70  ...               0                       0                   0
# 15      69  ...               0                       0                   0
# 20      66  ...               0                       0                   0
# 29      69  ...               0                       0                   0
#
#     father_Wootton Bassett  father_Yeats  father_Youmzain  father_Zambezi Sun  \
# 10                       0             0                0                   0
# 12                       0             0                0                   0
# 15                       0             0                0                   0
# 20                       0             0                0                   0
# 29                       0             0                0                   0
#
#     father_Zanzibari  father_Zebedee  father_Zoffany
# 10                 0               0               0
# 12                 0               0               0
# 15                 0               0               0
# 20                 0               0               0
# 29                 0               0               0
#
# [5 rows x 407 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = converted_data['res_win']
X = converted_data.drop(columns=['res_win'])

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
input_features = len(X_train_scaled[0])
input_features
# Out:
# 406

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train_scaled[0])
neurons_hidden_layer1 = 456
neurons_hidden_layer2 = 328
neurons_hidden_layer3 = 176

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units = neurons_hidden_layer1, activation="relu", input_dim = input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units = neurons_hidden_layer2, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units = neurons_hidden_layer3, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 456)               185592
#
#  dense_5 (Dense)             (None, 328)               149896
#
#  dense_6 (Dense)             (None, 176)               57904
#
#  dense_7 (Dense)             (None, 1)                 177
#
# =================================================================
# Total params: 393,569
# Trainable params: 393,569
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs = 150)
# Out:
# Epoch 1/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.5746 - accuracy: 0.7006
# Epoch 2/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.4732 - accuracy: 0.7732
# Epoch 3/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.4130 - accuracy: 0.8099
# Epoch 4/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.3734 - accuracy: 0.8279
# Epoch 5/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.3499 - accuracy: 0.8421
# Epoch 6/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.3313 - accuracy: 0.8509
# Epoch 7/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.3143 - accuracy: 0.8609
# Epoch 8/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.3027 - accuracy: 0.8646
# Epoch 9/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.2916 - accuracy: 0.8715
# Epoch 10/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.2821 - accuracy: 0.8756
# Epoch 11/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.2682 - accuracy: 0.8769
# Epoch 12/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.2646 - accuracy: 0.8823
# Epoch 13/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.2529 - accuracy: 0.8827
# Epoch 14/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.2428 - accuracy: 0.8893
# Epoch 15/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.2315 - accuracy: 0.8939
# Epoch 16/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.2255 - accuracy: 0.8951
# Epoch 17/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.2141 - accuracy: 0.9021
# Epoch 18/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.2064 - accuracy: 0.9033
# Epoch 19/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.1997 - accuracy: 0.9060
# Epoch 20/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.1928 - accuracy: 0.9087
# Epoch 21/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.1761 - accuracy: 0.9158
# Epoch 22/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.1729 - accuracy: 0.9210
# Epoch 23/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.1659 - accuracy: 0.9246
# Epoch 24/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.1560 - accuracy: 0.9279
# Epoch 25/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.1471 - accuracy: 0.9324
# Epoch 26/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.1386 - accuracy: 0.9383
# Epoch 27/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.1364 - accuracy: 0.9418
# Epoch 28/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.1254 - accuracy: 0.9460
# Epoch 29/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.1153 - accuracy: 0.9515
# Epoch 30/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.1129 - accuracy: 0.9525
# Epoch 31/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.1096 - accuracy: 0.9541
# Epoch 32/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.1070 - accuracy: 0.9559
# Epoch 33/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0981 - accuracy: 0.9598
# Epoch 34/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0892 - accuracy: 0.9624
# Epoch 35/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0885 - accuracy: 0.9648
# Epoch 36/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0786 - accuracy: 0.9689
# Epoch 37/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0822 - accuracy: 0.9684
# Epoch 38/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0814 - accuracy: 0.9691
# Epoch 39/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0754 - accuracy: 0.9726
# Epoch 40/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0717 - accuracy: 0.9723
# Epoch 41/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0645 - accuracy: 0.9761
# Epoch 42/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0648 - accuracy: 0.9746
# Epoch 43/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0700 - accuracy: 0.9731
# Epoch 44/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0660 - accuracy: 0.9746
# Epoch 45/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0567 - accuracy: 0.9776
# Epoch 46/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0637 - accuracy: 0.9763
# Epoch 47/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0559 - accuracy: 0.9788
# Epoch 48/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0490 - accuracy: 0.9805
# Epoch 49/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0542 - accuracy: 0.9794
# Epoch 50/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0579 - accuracy: 0.9793
# Epoch 51/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0536 - accuracy: 0.9809
# Epoch 52/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0503 - accuracy: 0.9814
# Epoch 53/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0486 - accuracy: 0.9823
# Epoch 54/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0494 - accuracy: 0.9819
# Epoch 55/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0457 - accuracy: 0.9850
# Epoch 56/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0462 - accuracy: 0.9840
# Epoch 57/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0464 - accuracy: 0.9841
# Epoch 58/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0450 - accuracy: 0.9842
# Epoch 59/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0401 - accuracy: 0.9863
# Epoch 60/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0379 - accuracy: 0.9864
# Epoch 61/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0347 - accuracy: 0.9876
# Epoch 62/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0388 - accuracy: 0.9868
# Epoch 63/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0446 - accuracy: 0.9831
# Epoch 64/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0418 - accuracy: 0.9856
# Epoch 65/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0321 - accuracy: 0.9894
# Epoch 66/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0353 - accuracy: 0.9878
# Epoch 67/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0407 - accuracy: 0.9863
# Epoch 68/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0443 - accuracy: 0.9854
# Epoch 69/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0326 - accuracy: 0.9902
# Epoch 70/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0295 - accuracy: 0.9898
# Epoch 71/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0334 - accuracy: 0.9888
# Epoch 72/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0341 - accuracy: 0.9888
# Epoch 73/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0339 - accuracy: 0.9883
# Epoch 74/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0359 - accuracy: 0.9880
# Epoch 75/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0394 - accuracy: 0.9863
# Epoch 76/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0313 - accuracy: 0.9903
# Epoch 77/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0257 - accuracy: 0.9908
# Epoch 78/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0259 - accuracy: 0.9917
# Epoch 79/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0217 - accuracy: 0.9931
# Epoch 80/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0234 - accuracy: 0.9922
# Epoch 81/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0164 - accuracy: 0.9938
# Epoch 82/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0240 - accuracy: 0.9919
# Epoch 83/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0393 - accuracy: 0.9877
# Epoch 84/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0384 - accuracy: 0.9873
# Epoch 85/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0307 - accuracy: 0.9910
# Epoch 86/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0259 - accuracy: 0.9914
# Epoch 87/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0215 - accuracy: 0.9933
# Epoch 88/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0235 - accuracy: 0.9928
# Epoch 89/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0264 - accuracy: 0.9915
# Epoch 90/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0255 - accuracy: 0.9916
# Epoch 91/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0231 - accuracy: 0.9917
# Epoch 92/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0226 - accuracy: 0.9929
# Epoch 93/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0212 - accuracy: 0.9933
# Epoch 94/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0160 - accuracy: 0.9939
# Epoch 95/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0140 - accuracy: 0.9949
# Epoch 96/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0213 - accuracy: 0.9926
# Epoch 97/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0265 - accuracy: 0.9919
# Epoch 98/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0249 - accuracy: 0.9917
# Epoch 99/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0276 - accuracy: 0.9920
# Epoch 100/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0278 - accuracy: 0.9922
# Epoch 101/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0187 - accuracy: 0.9941
# Epoch 102/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0235 - accuracy: 0.9932
# Epoch 103/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0221 - accuracy: 0.9931
# Epoch 104/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0230 - accuracy: 0.9932
# Epoch 105/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0196 - accuracy: 0.9937
# Epoch 106/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0184 - accuracy: 0.9938
# Epoch 107/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0199 - accuracy: 0.9943
# Epoch 108/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0184 - accuracy: 0.9944
# Epoch 109/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0162 - accuracy: 0.9951
# Epoch 110/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0182 - accuracy: 0.9943
# Epoch 111/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0177 - accuracy: 0.9942
# Epoch 112/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0191 - accuracy: 0.9939
# Epoch 113/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0180 - accuracy: 0.9946
# Epoch 114/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0256 - accuracy: 0.9924
# Epoch 115/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0213 - accuracy: 0.9940
# Epoch 116/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0208 - accuracy: 0.9936
# Epoch 117/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0175 - accuracy: 0.9940
# Epoch 118/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0214 - accuracy: 0.9938
# Epoch 119/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0198 - accuracy: 0.9946
# Epoch 120/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0130 - accuracy: 0.9961
# Epoch 121/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0147 - accuracy: 0.9955
# Epoch 122/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0181 - accuracy: 0.9947
# Epoch 123/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0179 - accuracy: 0.9952
# Epoch 124/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0191 - accuracy: 0.9948
# Epoch 125/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0199 - accuracy: 0.9943
# Epoch 126/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0164 - accuracy: 0.9955
# Epoch 127/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0134 - accuracy: 0.9962
# Epoch 128/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0126 - accuracy: 0.9960
# Epoch 129/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0195 - accuracy: 0.9952
# Epoch 130/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0204 - accuracy: 0.9934
# Epoch 131/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0186 - accuracy: 0.9950
# Epoch 132/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0165 - accuracy: 0.9945
# Epoch 133/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0158 - accuracy: 0.9954
# Epoch 134/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0170 - accuracy: 0.9951
# Epoch 135/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0159 - accuracy: 0.9955
# Epoch 136/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0160 - accuracy: 0.9950
# Epoch 137/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0167 - accuracy: 0.9948
# Epoch 138/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0221 - accuracy: 0.9941
# Epoch 139/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0120 - accuracy: 0.9963
# Epoch 140/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0117 - accuracy: 0.9966
# Epoch 141/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0101 - accuracy: 0.9964
# Epoch 142/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0086 - accuracy: 0.9973
# Epoch 143/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0115 - accuracy: 0.9965
# Epoch 144/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0132 - accuracy: 0.9968
# Epoch 145/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0089 - accuracy: 0.9979
# Epoch 146/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0115 - accuracy: 0.9969
# Epoch 147/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0118 - accuracy: 0.9963
# Epoch 148/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0162 - accuracy: 0.9962
# Epoch 149/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0226 - accuracy: 0.9934
# Epoch 150/150
# 492/492 [==============================] - 1s 2ms/step - loss: 0.0275 - accuracy: 0.9926

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 164/164 - 0s - loss: 1.4726 - accuracy: 0.8227 - 292ms/epoch - 2ms/step
# Loss: 1.4726359844207764, Accuracy: 0.8226760625839233

# %%
y_test.mean()
# Out:
# 0.5651841954571483

# %%
# Make predictions on the test data
y_pred = nn.predict(X_test_scaled)
y_pred_binary = (y_pred > 0.5).astype(int)
# Out:
# 164/164 [==============================] - 0s 671us/step

# %%
from sklearn.metrics import precision_score

precision = precision_score(y_test, y_pred_binary)
print("Precision:", precision)
# Out:
# Precision: 0.8479452054794521

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_binary))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.81      0.80      2278
#          1.0       0.85      0.84      0.84      2961
#
#     accuracy                           0.82      5239
#    macro avg       0.82      0.82      0.82      5239
# weighted avg       0.82      0.82      0.82      5239

# %%
# Export our model to HDF5 file
# nn.save('h5_files/AlphabetSoup_Model4.h5')
