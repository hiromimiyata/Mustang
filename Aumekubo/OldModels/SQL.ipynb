# %%
import csv
import sqlite3

# %%
def csv_to_sqlite(csv_file, db_file, table_name):
    # Connect to the SQLite database
    conn = sqlite3.connect(db_file)
    cursor = conn.cursor()

    # Create the table in the database
    create_table_query = f"CREATE TABLE IF NOT EXISTS {table_name} ({','.join(columns)})"
    cursor.execute(create_table_query)

    # Read the CSV file and insert data into the table
    with open(csv_file, 'r') as file:
        csv_reader = csv.reader(file)
        next(csv_reader)  # Skip the header row

        insert_query = f"INSERT INTO {table_name} VALUES ({','.join(['?'] * len(columns))})"
        cursor.executemany(insert_query, csv_reader)

    # Commit the changes and close the connection
    conn.commit()
    conn.close()

# %%
 # Import the dependencies.
    
import pandas as pd
from pathlib import Path
from sqlalchemy import create_engine, text, ForeignKey,Column, String, Interger, CHAR
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
Base = declarative_base()

# Create a reference to the file. 
horse_database_path = Path(r'C:\Users\aumek\OneDrive\Desktop\Git_Personnal_Rep\Resource_mustang\horses_2020.csv')

# Read the CSV file into pandas
df_horses = pd.read_csv(database_path)
df_horses.head()
# Out:
# C:\Users\aumek\AppData\Local\Temp\ipykernel_23272\2405694757.py:11: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_horses = pd.read_csv(database_path)
#      rid          horseName  age  saddle  decimalPrice  isFav
# 0  10312         Waterproof  4.0     9.0      0.076923      0  \
# 1  10312         Eva's Diva  6.0     7.0      0.444444      1
# 2  10312   Incredible Dream  7.0     5.0      0.019608      0
# 3  10312  Hats Off To Larry  6.0     4.0      0.230769      0
# 4  10312             Taqwaa  7.0     6.0      0.038462      0
#
#        trainerName       jockeyName  position positionL  ...     OR
# 0  Shaun Keightley   Brendan Powell         1       NaN  ...    NaN  \
# 1   Phil Middleton       Mr Sam Lee         2        15  ...  110.0
# 2     Conrad Allen     Joshua Moore         3       5.5  ...    NaN
# 3     Mick Channon   Marc Goldstein         4        10  ...    NaN
# ...

# %%
# Create an engine that can talk to the database
engine = create_engine(f"sqlite:///{horse_database_path}")

# %%
# Query All Records in the the Database
query = text("SELECT * FROM horses_2020")
data = engine.execute(query)

for record in data:
    print(record)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818                 if not evt_handled:
# -> 1819                     self.dialect.do_execute(
#    1820                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#
# DatabaseError: file is not a database
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# ...

# %%
# Create a reference to the file. 
database_path = Path(r'C:\Users\aumek\OneDrive\Desktop\Git_Personnal_Rep\Resource_mustang\races_2020.csv')

# Read the CSV file into pandas
df = pd.read_csv(database_path)
df.head(5)
# Out:
#      rid            course   time      date
# 0  10312          Fakenham  02:55  20/01/01  \
# 1  10896        Cheltenham  03:50  20/01/01
# 2  23038     Tramore (IRE)  02:55  20/01/01
# 3  23986  Fairyhouse (IRE)  02:40  20/01/01
# 4  25123  Fairyhouse (IRE)  02:05  20/01/01
#
#                                                title   rclass    band  ages
# 0               Happy New Year Maiden Hurdle (Div I)  Class 4     NaN  4yo+  \
# 1  EBF Stallions &amp; Cheltenham Pony Club (A St...  Class 1     NaN   4yo
# 2        Jerry O'Donovan Memorial Rated Novice Chase      NaN     NaN  5yo+
# 3  Follow Fairyhouse On Social Media Beginners Chase      NaN     NaN  5yo+
# 4  Fairyhouse Launches New Brand In 2020 Handicap...      NaN  80-109  4yo+
#
#   distance     condition     hurdles
# 0       2m  Good To Soft   9 hurdles  \
# 1     1m6f          Soft         NaN
# 2       2m          Soft   12 fences
# 3     2m5f      Yielding   13 fences
# 4       3m      Yielding  13 hurdles
#
# ...
