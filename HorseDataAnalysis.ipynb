# %%
 # Import the modules
import pandas as pd
import hvplot.pandas
from pathlib import Path

# %%
 # Set the file path
file_path = Path("Merged_Data/merged_data.csv")

# Read the csv file into a pandas DataFrame
horse_df = pd.read_csv(file_path)

# Review the DataFrame
horse_df.head()
# Out:
# C:\Users\yukiz\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3186: DtypeWarning: Columns (11,19,46) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0    rid    course   time      date  \
# 0           0  10312  Fakenham  02:55  20/01/01
# 1           1  10312  Fakenham  02:55  20/01/01
# 2           2  10312  Fakenham  02:55  20/01/01
# 3           3  10312  Fakenham  02:55  20/01/01
# 4           4  10312  Fakenham  02:55  20/01/01
#
#                                   title   rclass band  ages distance  ...  \
# 0  Happy New Year Maiden Hurdle (Div I)  Class 4  NaN  4yo+       2m  ...
# 1  Happy New Year Maiden Hurdle (Div I)  Class 4  NaN  4yo+       2m  ...
# 2  Happy New Year Maiden Hurdle (Div I)  Class 4  NaN  4yo+       2m  ...
# 3  Happy New Year Maiden Hurdle (Div I)  Class 4  NaN  4yo+       2m  ...
# ...

# %%
horse_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149589 entries, 0 to 149588
# Data columns (total 47 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    149589 non-null  int64
#  1   rid           149589 non-null  int64
#  2   course        149589 non-null  object
#  3   time          149589 non-null  object
#  4   date          149589 non-null  object
#  5   title         149589 non-null  object
#  6   rclass        67157 non-null   object
#  7   band          54023 non-null   object
#  8   ages          149589 non-null  object
#  9   distance      149589 non-null  object
#  10  condition     149589 non-null  object
#  11  hurdles       29784 non-null   object
#  12  prizes        149589 non-null  object
#  13  winningTime   149589 non-null  float64
#  14  prize         149589 non-null  int64
#  15  metric        149589 non-null  float64
#  16  countryCode   149589 non-null  object
# ...

# %%
#Cleaning the data
#drop title and headgear columns
horse_df = horse_df.drop(["title", "headGear", "overWeight","hurdles"], axis = 1)
horse_df.head()
# Out:
#    Unnamed: 0    rid    course   time      date   rclass band  ages distance  \
# 0           0  10312  Fakenham  02:55  20/01/01  Class 4  NaN  4yo+       2m
# 1           1  10312  Fakenham  02:55  20/01/01  Class 4  NaN  4yo+       2m
# 2           2  10312  Fakenham  02:55  20/01/01  Class 4  NaN  4yo+       2m
# 3           3  10312  Fakenham  02:55  20/01/01  Class 4  NaN  4yo+       2m
# 4           4  10312  Fakenham  02:55  20/01/01  Class 4  NaN  4yo+       2m
#
#       condition  ...     OR        father          mother            gfather  \
# 0  Good To Soft  ...    NaN      Pour Moi  Laughing Water  Duke Of Marmalade
# 1  Good To Soft  ...  110.0       Getaway        Shouette     Sadler's Wells
# 2  Good To Soft  ...    NaN  Vale Of York        Finnmark            Halling
# 3  Good To Soft  ...    NaN  Sixties Icon    Highland Jig       Norse Dancer
# 4  Good To Soft  ...    NaN       Iffraaj   Hallowed Park           Barathea
#
# ...
