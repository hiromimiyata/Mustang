# %% [markdown]
# # ML Model Horse Racing Predictions
# #### Create an ML model that can predict whether a horse has a good chance of winning a race, based on the horse's features

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
cleaned_data_df = pd.read_csv("Data_Racing/International_Data/cleaned_data_df.csv")
cleaned_data_df.head()
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# 2023-07-19 19:08:02.929270: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#    Unnamed: 0  ages  metric  ncond  age  saddle  decimalPrice  isFav    RPR  \
# 0           1  4yo+  3218.0     10  6.0     7.0      0.444444      1   96.0
# 1          26  5yo+  3218.0      5  8.0     1.0      0.266667      1  115.0
# 2          27  5yo+  3218.0      5  9.0     2.0      0.125000      0  108.0
# 3          43  4yo+  4827.0      6  7.0    13.0      0.076923      0   95.0
# 4          44  4yo+  4827.0      6  8.0     2.0      0.076923      0  119.0
#
#      TR     OR      father  weight  res_win
# 0  89.0  110.0     Getaway      65      0.0
# 1  33.0  109.0  Beneficial      73      0.0
# 2  29.0  103.0  Beneficial      68      0.0
# 3  39.0   83.0    Kalanisi      63      1.0
# 4  64.0  108.0         Ask      71      0.0

# %%
cleaned_data_df = cleaned_data_df.drop(columns = "Unnamed: 0")

# %%
# Determine the number of unique values in each column.
cleaned_data_df.nunique()
# Out:
# ages             16
# metric           52
# ncond            13
# age              14
# saddle           29
# decimalPrice     79
# isFav             2
# RPR             165
# TR              157
# OR              149
# father          327
# weight           32
# res_win           2
# dtype: int64

# %% [markdown]
# ## Select equal res_win values

# %%
# Look at value counts for binning
res_win_counts = cleaned_data_df["res_win"].value_counts()
class_count = res_win_counts.min()
class_count
# Out:
# 3169

# %%
res_win_equal = pd.concat([cleaned_data_df[cleaned_data_df.res_win==0].sample(n=class_count), 
                           cleaned_data_df[cleaned_data_df.res_win==1].sample(n=class_count)])
res_win_equal = res_win_equal.sort_index()
res_win_equal
# Out:
#        ages  metric  ncond  age  saddle  decimalPrice  isFav    RPR    TR  \
# 3      4yo+  4827.0      6  7.0    13.0      0.076923      0   95.0  39.0
# 10     4yo+  1005.0      0  5.0     4.0      0.047619      0   91.0  69.0
# 16     5yo+  4122.5     10  9.0     1.0      0.090909      0  150.0  56.0
# 18     5yo+  4122.5     10  8.0    11.0      0.105263      0  135.0  40.0
# 21     5yo+  5832.0     10  9.0     4.0      0.222222      0  113.0  39.0
# ...     ...     ...    ...  ...     ...           ...    ...    ...   ...
# 24897  3yo+  1609.0      0  6.0     9.0      0.181818      0   90.0  41.0
# 24905  4yo+  3821.0      5  6.0     2.0      0.222222      0  134.0  40.0
# 24913  4yo+  4022.0      5  7.0     5.0      0.153846      0  144.0  82.0
# 24919  4yo+  4725.5      9  8.0     1.0      0.076923      0  141.0   3.0
# 24920  4yo+  5329.5      5  7.0     2.0      0.250000      1  107.0  10.0
#
#           OR           father  weight  res_win
# 3       83.0         Kalanisi      63      1.0
# 10      83.0       Showcasing      58      1.0
# 16     140.0     Dylan Thomas      73      1.0
# 18     127.0         Fair Mix      69      0.0
# 21     102.0  September Storm      74      1.0
# ...      ...              ...     ...      ...
# 24897   82.0  Rio De La Plata      56      1.0
# 24905  135.0           Jeremy      69      1.0
# 24913  129.0        Poliglote      70      1.0
# 24919  139.0          Shantou      75      1.0
# 24920  102.0  Midnight Legend      70      1.0
#
# [6338 rows x 13 columns]

# %% [markdown]
# ## Convert and Standardize Data

# %%
# Convert categorical data to numeric with `pd.get_dummies`
converted_data = pd.get_dummies(res_win_equal)
converted_data.head()
# Out:
#     metric  ncond  age  saddle  decimalPrice  isFav    RPR    TR     OR  \
# 3   4827.0      6  7.0    13.0      0.076923      0   95.0  39.0   83.0
# 10  1005.0      0  5.0     4.0      0.047619      0   91.0  69.0   83.0
# 16  4122.5     10  9.0     1.0      0.090909      0  150.0  56.0  140.0
# 18  4122.5     10  8.0    11.0      0.105263      0  135.0  40.0  127.0
# 21  5832.0     10  9.0     4.0      0.222222      0  113.0  39.0  102.0
#
#     weight  ...  father_War Front  father_Well Chosen  father_Westerner  \
# 3       63  ...                 0                   0                 0
# 10      58  ...                 0                   0                 0
# 16      73  ...                 0                   0                 0
# 18      69  ...                 0                   0                 0
# 21      74  ...                 0                   0                 0
#
#     father_Whipper  father_Winged Love  father_Wootton Bassett  father_Yeats  \
# 3                0                   0                       0             0
# 10               0                   0                       0             0
# 16               0                   0                       0             0
# 18               0                   0                       0             0
# 21               0                   0                       0             0
#
#     father_Youmzain  father_Zebedee  father_Zoffany
# 3                 0               0               0
# 10                0               0               0
# 16                0               0               0
# 18                0               0               0
# 21                0               0               0
#
# [5 rows x 338 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = converted_data['res_win']
X = converted_data.drop(columns=['res_win'])

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
input_features = len(X_train_scaled[0])
input_features
# Out:
# 337

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train_scaled[0])
neurons_hidden_layer1 = 356
neurons_hidden_layer2 = 268
neurons_hidden_layer3 = 176

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units = neurons_hidden_layer1, activation="relu", input_dim = input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units = neurons_hidden_layer2, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units = neurons_hidden_layer3, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 356)               120328
#
#  dense_5 (Dense)             (None, 268)               95676
#
#  dense_6 (Dense)             (None, 176)               47344
#
#  dense_7 (Dense)             (None, 1)                 177
#
# =================================================================
# Total params: 263,525
# Trainable params: 263,525
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs = 150)
# Out:
# Epoch 1/150
# 149/149 [==============================] - 1s 1ms/step - loss: 0.6267 - accuracy: 0.6510
# Epoch 2/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.5108 - accuracy: 0.7366
# Epoch 3/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4631 - accuracy: 0.7616
# Epoch 4/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.4296 - accuracy: 0.7862
# Epoch 5/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3986 - accuracy: 0.7991
# Epoch 6/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3713 - accuracy: 0.8102
# Epoch 7/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3459 - accuracy: 0.8287
# Epoch 8/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3245 - accuracy: 0.8418
# Epoch 9/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.3029 - accuracy: 0.8588
# Epoch 10/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.2835 - accuracy: 0.8689
# Epoch 11/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.2648 - accuracy: 0.8767
# Epoch 12/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.2459 - accuracy: 0.8813
# Epoch 13/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.2276 - accuracy: 0.8956
# Epoch 14/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.2153 - accuracy: 0.9013
# Epoch 15/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.1987 - accuracy: 0.9057
# Epoch 16/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.1871 - accuracy: 0.9123
# Epoch 17/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.1696 - accuracy: 0.9215
# Epoch 18/150
# 149/149 [==============================] - 0s 2ms/step - loss: 0.1594 - accuracy: 0.9312
# Epoch 19/150
# 149/149 [==============================] - 0s 2ms/step - loss: 0.1546 - accuracy: 0.9314
# Epoch 20/150
# 149/149 [==============================] - 0s 2ms/step - loss: 0.1406 - accuracy: 0.9367
# Epoch 21/150
# 149/149 [==============================] - 0s 2ms/step - loss: 0.1279 - accuracy: 0.9438
# Epoch 22/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.1156 - accuracy: 0.9495
# Epoch 23/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.1001 - accuracy: 0.9541
# Epoch 24/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.1035 - accuracy: 0.9543
# Epoch 25/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0993 - accuracy: 0.9579
# Epoch 26/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.1018 - accuracy: 0.9577
# Epoch 27/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0888 - accuracy: 0.9630
# Epoch 28/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0722 - accuracy: 0.9701
# Epoch 29/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0618 - accuracy: 0.9720
# Epoch 30/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0618 - accuracy: 0.9720
# Epoch 31/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0641 - accuracy: 0.9745
# Epoch 32/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0678 - accuracy: 0.9743
# Epoch 33/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0654 - accuracy: 0.9756
# Epoch 34/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0507 - accuracy: 0.9796
# Epoch 35/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0486 - accuracy: 0.9823
# Epoch 36/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0545 - accuracy: 0.9821
# Epoch 37/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0498 - accuracy: 0.9809
# Epoch 38/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0465 - accuracy: 0.9834
# Epoch 39/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0546 - accuracy: 0.9794
# Epoch 40/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0530 - accuracy: 0.9815
# Epoch 41/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0378 - accuracy: 0.9876
# Epoch 42/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0250 - accuracy: 0.9914
# Epoch 43/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0280 - accuracy: 0.9891
# Epoch 44/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0417 - accuracy: 0.9874
# Epoch 45/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0475 - accuracy: 0.9849
# Epoch 46/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0498 - accuracy: 0.9836
# Epoch 47/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0480 - accuracy: 0.9861
# Epoch 48/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0338 - accuracy: 0.9880
# Epoch 49/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0358 - accuracy: 0.9861
# Epoch 50/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0287 - accuracy: 0.9905
# Epoch 51/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0208 - accuracy: 0.9924
# Epoch 52/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0281 - accuracy: 0.9910
# Epoch 53/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0210 - accuracy: 0.9910
# Epoch 54/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0331 - accuracy: 0.9891
# Epoch 55/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0437 - accuracy: 0.9865
# Epoch 56/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0321 - accuracy: 0.9893
# Epoch 57/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0398 - accuracy: 0.9872
# Epoch 58/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0456 - accuracy: 0.9857
# Epoch 59/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0549 - accuracy: 0.9857
# Epoch 60/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0544 - accuracy: 0.9870
# Epoch 61/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0399 - accuracy: 0.9878
# Epoch 62/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0422 - accuracy: 0.9876
# Epoch 63/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0312 - accuracy: 0.9910
# Epoch 64/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0285 - accuracy: 0.9918
# Epoch 65/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0329 - accuracy: 0.9891
# Epoch 66/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0366 - accuracy: 0.9914
# Epoch 67/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0293 - accuracy: 0.9916
# Epoch 68/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0123 - accuracy: 0.9943
# Epoch 69/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0195 - accuracy: 0.9916
# Epoch 70/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.9935
# Epoch 71/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0148 - accuracy: 0.9960
# Epoch 72/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0083 - accuracy: 0.9966
# Epoch 73/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0089 - accuracy: 0.9968
# Epoch 74/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0040 - accuracy: 0.9981
# Epoch 75/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0045 - accuracy: 0.9983
# Epoch 76/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0052 - accuracy: 0.9977
# Epoch 77/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0069 - accuracy: 0.9971
# Epoch 78/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0093 - accuracy: 0.9968
# Epoch 79/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0293 - accuracy: 0.9916
# Epoch 80/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0333 - accuracy: 0.9907
# Epoch 81/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0654 - accuracy: 0.9811
# Epoch 82/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0622 - accuracy: 0.9792
# Epoch 83/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0438 - accuracy: 0.9851
# Epoch 84/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0349 - accuracy: 0.9914
# Epoch 85/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0299 - accuracy: 0.9912
# Epoch 86/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0111 - accuracy: 0.9971
# Epoch 87/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0104 - accuracy: 0.9958
# Epoch 88/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0082 - accuracy: 0.9971
# Epoch 89/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0093 - accuracy: 0.9960
# Epoch 90/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0104 - accuracy: 0.9964
# Epoch 91/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0050 - accuracy: 0.9981
# Epoch 92/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0069 - accuracy: 0.9966
# Epoch 93/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0088 - accuracy: 0.9975
# Epoch 94/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0067 - accuracy: 0.9983
# Epoch 95/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0036 - accuracy: 0.9985
# Epoch 96/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0026 - accuracy: 0.9987
# Epoch 97/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0043 - accuracy: 0.9977
# Epoch 98/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0037 - accuracy: 0.9979
# Epoch 99/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0024 - accuracy: 0.9989
# Epoch 100/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0019 - accuracy: 0.9989
# Epoch 101/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0028 - accuracy: 0.9985
# Epoch 102/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0056 - accuracy: 0.9983
# Epoch 103/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0052 - accuracy: 0.9983
# Epoch 104/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0285 - accuracy: 0.9916
# Epoch 105/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0748 - accuracy: 0.9750
# Epoch 106/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0868 - accuracy: 0.9716
# Epoch 107/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0564 - accuracy: 0.9834
# Epoch 108/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0323 - accuracy: 0.9903
# Epoch 109/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0150 - accuracy: 0.9966
# Epoch 110/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0094 - accuracy: 0.9966
# Epoch 111/150
# 149/149 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 0.9962
# Epoch 112/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0098 - accuracy: 0.9968
# Epoch 113/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0101 - accuracy: 0.9979
# Epoch 114/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0043 - accuracy: 0.9987
# Epoch 115/150
# 149/149 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 0.9971
# Epoch 116/150
# 149/149 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 0.9981
# Epoch 117/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0089 - accuracy: 0.9975
# Epoch 118/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0102 - accuracy: 0.9966
# Epoch 119/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0168 - accuracy: 0.9958
# Epoch 120/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0134 - accuracy: 0.9964
# Epoch 121/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0254 - accuracy: 0.9928
# Epoch 122/150
# 149/149 [==============================] - 0s 2ms/step - loss: 0.0264 - accuracy: 0.9935
# Epoch 123/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0191 - accuracy: 0.9945
# Epoch 124/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0145 - accuracy: 0.9956
# Epoch 125/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0074 - accuracy: 0.9977
# Epoch 126/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0073 - accuracy: 0.9987
# Epoch 127/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0041 - accuracy: 0.9987
# Epoch 128/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0088 - accuracy: 0.9981
# Epoch 129/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0074 - accuracy: 0.9981
# Epoch 130/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0078 - accuracy: 0.9985
# Epoch 131/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0345 - accuracy: 0.9922
# Epoch 132/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0227 - accuracy: 0.9941
# Epoch 133/150
# 149/149 [==============================] - 0s 2ms/step - loss: 0.0191 - accuracy: 0.9950
# Epoch 134/150
# 149/149 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 0.9952
# Epoch 135/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0105 - accuracy: 0.9966
# Epoch 136/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0080 - accuracy: 0.9973
# Epoch 137/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0029 - accuracy: 0.9989
# Epoch 138/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0028 - accuracy: 0.9996
# Epoch 139/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0043 - accuracy: 0.9987
# Epoch 140/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0018 - accuracy: 0.9992
# Epoch 141/150
# 149/149 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 0.9992
# Epoch 142/150
# 149/149 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 0.9989
# Epoch 143/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0012 - accuracy: 0.9996
# Epoch 144/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0013 - accuracy: 0.9994
# Epoch 145/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0013 - accuracy: 0.9992
# Epoch 146/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0011 - accuracy: 0.9992
# Epoch 147/150
# 149/149 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 0.9989
# Epoch 148/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0013 - accuracy: 0.9992
# Epoch 149/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0016 - accuracy: 0.9994
# Epoch 150/150
# 149/149 [==============================] - 0s 1ms/step - loss: 0.0315 - accuracy: 0.9910

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 50/50 - 0s - loss: 1.3882 - accuracy: 0.7836 - 101ms/epoch - 2ms/step
# Loss: 1.3882046937942505, Accuracy: 0.7835962176322937

# %%
(y_test == 0).mean()
# Out:
# 0.5072555205047319

# %%
# Make predictions on the test data
y_pred = nn.predict(X_test_scaled)
y_pred_binary = (y_pred > 0.5).astype(int)
# Out:
# 50/50 [==============================] - 0s 660us/step

# %%
from sklearn.metrics import precision_score

precision = precision_score(y_test, y_pred_binary)
print("Precision:", precision)
# Out:
# Precision: 0.7765151515151515

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_binary))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.78      0.79       804
#          1.0       0.78      0.79      0.78       781
#
#     accuracy                           0.78      1585
#    macro avg       0.78      0.78      0.78      1585
# weighted avg       0.78      0.78      0.78      1585

# %%
# Export our model to HDF5 file
# nn.save('h5_files/AlphabetSoup_Model4.h5')
