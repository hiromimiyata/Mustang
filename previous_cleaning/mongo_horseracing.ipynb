# %%
from pymongo import MongoClient
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'classDB', 'config', 'epa', 'fruitsDB', 'horse_racing', 'local', 'met', 'petsitly_marketing', 'travel_db', 'uk_food']

# %%
# assign the database to a variable name
db = mongo['horse_racing']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['horses', 'races']

# %%
# review a document in the customer_list collection
print(db.horses.find_one())
# Out:
# {'_id': ObjectId('64b5ff95f05d1290f2aeec99'), 'rid': 10312, 'horseName': 'Dandy Times', 'age': 7.0, 'saddle': 2.0, 'decimalPrice': 0.0196078431372549, 'isFav': 0, 'trainerName': 'Joanne Thomason-Murphy', 'jockeyName': 'Page Fuller', 'position': 7, 'positionL': 21, 'dist': 58.75, 'weightSt': 11, 'weightLb': 2, 'overWeight': '', 'outHandicap': '', 'headGear': '', 'RPR': 61.0, 'TR': 35.0, 'OR': '', 'father': 'Central Park', 'mother': 'Distinctly Flo Jo', 'gfather': 'Distinctly North', 'runners': 9, 'margin': 1.199095022624434, 'weight': 70, 'res_win': 0.0, 'res_place': 0.0, 'price': ''}

# %%
# review a document in the customer_list collection
print(db.races.find_one())
# Out:
# {'_id': ObjectId('64b5ffbc3d381e076bbf62c7'), 'rid': 23038, 'course': 'Tramore (IRE)', 'time': '02:55', 'date': '20/01/01', 'title': "Jerry O'Donovan Memorial Rated Novice Chase", 'rclass': '', 'band': '', 'ages': '5yo+', 'distance': '2m', 'condition': 'Soft', 'hurdles': '12 fences', 'prizes': '[7387.5, 2387.5, 1137.5, 512.5, 262.5, 137.5]', 'winningTime': 266.4, 'prize': 11826, 'metric': 3218, 'countryCode': 'IE', 'ncond': 5, 'class': 0, 'currency': ''}

# %%
horses = db['horses']
races = db['races']

# %%
horse_data = list(horses.find())
race_data = list(races.find())

# %%
horse_df = pd.DataFrame(horse_data)
horse_df.head()
# Out:
#                         _id    rid         horseName  age saddle  \
# 0  64b5ff95f05d1290f2aeec99  10312       Dandy Times  7.0      2
# 1  64b5ff95f05d1290f2aeec9a  10312              Bran  5.0      1
# 2  64b5ff95f05d1290f2aeec9b  10312     George Gently  7.0      3
# 3  64b5ff95f05d1290f2aeec9c  10312  Incredible Dream  7.0      5
# 4  64b5ff95f05d1290f2aeec9d  10896          Audacity  4.0      1
#
#    decimalPrice  isFav             trainerName       jockeyName  position  \
# 0      0.019608      0  Joanne Thomason-Murphy      Page Fuller         7
# 1      0.117647      0          Stuart Edmunds  Ciaran Gethings        40
# 2      0.222222      0            Justin Landy       Harry Reed         6
# 3      0.019608      0            Conrad Allen     Joshua Moore         3
# 4      0.058824      0         Warren Greatrex    Gavin Sheehan         1
#
#    ...   OR        father             mother            gfather runners  \
# 0  ...       Central Park  Distinctly Flo Jo   Distinctly North       9
# 1  ...             Sakhee        Cup Of Love            Behrens       9
# 2  ...  114    Gentlewave           Sindibad  Rock Of Gibraltar       9
# 3  ...       Vale Of York           Finnmark            Halling       9
# 4  ...            Pivotal           Carlanda              Lando      16
#
#      margin weight res_win res_place price
# 0  1.199095     70     0.0       0.0
# 1  1.199095     72     0.0       0.0
# 2  1.199095     70     0.0       0.0
# 3  1.199095     72     0.0       1.0
# 4  1.261934     68     1.0       1.0
#
# [5 rows x 29 columns]

# %%
race_df = pd.DataFrame(race_data)
race_df.head()
# Out:
#                         _id     rid             course   time      date  \
# 0  64b5ffbc3d381e076bbf62c7   23038      Tramore (IRE)  02:55  20/01/01
# 1  64b5ffbc3d381e076bbf62c8  113785           Fakenham  12:35  20/01/01
# 2  64b5ffbc3d381e076bbf62c9  113831  Santa Anita (USA)  11:00  20/01/01
# 3  64b5ffbc3d381e076bbf62ca  113854       Sha Tin (HK)  04:15  20/01/01
# 4  64b5ffbc3d381e076bbf62cb  114207          Catterick  11:55  20/01/01
#
#                                                title   rclass   band  ages  \
# 0        Jerry O'Donovan Memorial Rated Novice Chase                  5yo+
# 1  Visit attheraces.com Amateur Riders' Handicap ...  Class 4  0-105  5yo+
# 2       Joe Hernandez Stakes (Grade 2) (4yo+) (Turf)                  4yo+
# 3   Palm Handicap (Class 4) (3yo+) (Course C) (Turf)                  3yo+
# 4      Every Race Live On Racing TV Beginners' Chase  Class 4         5yo+
#
#   distance     condition    hurdles  \
# 0       2m          Soft  12 fences
# 1     3m5f  Good To Soft  22 fences
# 2      5½f          Firm
# 3       6f          Good
# 4     3m1f  Good To Soft  19 fences
#
#                                               prizes  winningTime   prize  \
# 0      [7387.5, 2387.5, 1137.5, 512.5, 262.5, 137.5]       266.40   11826
# 1    [5490.32, 1702.8, 850.96, 425.92, 350.0, 350.0]       489.97    9170
# 2  [90225.56, 30075.19, 18045.11, 9022.56, 3007.5...        62.47  152257
# 3   [53306.58, 20574.47, 10754.84, 5611.22, 3273.21]        70.12   93520
# 4                                 [5458.32, 1602.72]       400.90    7061
#
#    metric countryCode  ncond  class currency
# 0  3218.0          IE      5      0
# 1  5832.0          GB     10      4
# 2  1105.5          US      8      0
# 3  1206.0          HK      1      0
# 4  5028.0          GB     10      4
